# %%
import pandas as pd
import numpy as np
import matplotlib as mlt
import statistics as stat
import seaborn as sns
from sklearn import preprocessing

# %%
data = pd.read_csv('Dataset3.csv',index_col=0)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 50000 entries, 0 to 49999
# Data columns (total 16 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   business_code           50000 non-null  object
#  1   cust_number             50000 non-null  object
#  2   name_customer           50000 non-null  object
#  3   clear_date              40000 non-null  object
#  4   posting_date            50000 non-null  object
#  5   document_create_date    50000 non-null  object
#  6   document_create_date.1  50000 non-null  object
#  7   due_in_date             50000 non-null  object
#  8   total_open_amount       50000 non-null  float64
#  9   baseline_create_date    50000 non-null  object
#  10  cust_payment_terms      50000 non-null  object
#  11  isOpen                  50000 non-null  int64
#  12  delay                   40000 non-null  float64
#  13  Time_given              50000 non-null  int64
# ...

# %%
data.head()
# Out:
#   business_code cust_number       name_customer  clear_date posting_date  \
# 0          U001   200769623        WAL-MAR corp  2020-11-02   2020-01-26
# 1          U001   200980828              BEN E   2019-08-08   2019-07-22
# 2          U001   200792734          MDV/ trust  2019-12-30   2019-09-14
# 3          CA02   140105686            SYSC llc         NaN   2020-03-30
# 4          U001   200769623  WAL-MAR foundation  2019-11-25   2019-11-13
#
#   document_create_date document_create_date.1 due_in_date  total_open_amount  \
# 0           2020-01-25             2020-01-26  2020-02-10        4054214.016
# 1           2019-07-22             2019-07-22  2019-08-11        5950348.020
# 2           2019-09-14             2019-09-14  2019-09-29         168363.342
# 3           2020-03-30             2020-03-30  2020-04-10         194055.357
# 4           2019-11-13             2019-11-13  2019-11-28        2475056.763
#
# ...

# %%
data['clear_date'] = pd.to_datetime(data['clear_date'])
data['posting_date'] = pd.to_datetime(data['posting_date'])
data['document_create_date'] = pd.to_datetime(data['document_create_date'])
data['document_create_date.1'] = pd.to_datetime(data['document_create_date.1'])
data['due_in_date'] = pd.to_datetime(data['due_in_date'])
data['baseline_create_date'] = pd.to_datetime(data['baseline_create_date'])
data['delay'] = (data['Time_taken']-data['Time_given'])

# %%
data.sort_index(axis=1,inplace=True)

# %%
data.head()
# Out:
#    Time_given  Time_taken  Time_variance baseline_create_date business_code  \
# 0          16       282.0          266.0           2020-01-26          U001
# 1          20        17.0           -3.0           2019-07-22          U001
# 2          15       107.0           92.0           2019-09-14          U001
# 3          11         NaN            NaN           2020-03-31          CA02
# 4          15        12.0           -3.0           2019-11-13          U001
#
#   clear_date cust_number cust_payment_terms  delay document_create_date  \
# 0 2020-11-02   200769623               NAH4  266.0           2020-01-25
# 1 2019-08-08   200980828               NAD1   -3.0           2019-07-22
# 2 2019-12-30   200792734               NAA8   92.0           2019-09-14
# 3        NaT   140105686               CA10    NaN           2020-03-30
# 4 2019-11-25   200769623               NAH4   -3.0           2019-11-13
#
# ...

# %%
data.to_csv('Dataset4.csv')

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 50000 entries, 0 to 49999
# Data columns (total 16 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Time_given              50000 non-null  int64
#  1   Time_taken              40000 non-null  float64
#  2   Time_variance           40000 non-null  float64
#  3   baseline_create_date    50000 non-null  datetime64[ns]
#  4   business_code           50000 non-null  object
#  5   clear_date              40000 non-null  datetime64[ns]
#  6   cust_number             50000 non-null  object
#  7   cust_payment_terms      50000 non-null  object
#  8   delay                   40000 non-null  float64
#  9   document_create_date    50000 non-null  datetime64[ns]
#  10  document_create_date.1  50000 non-null  datetime64[ns]
#  11  due_in_date             50000 non-null  datetime64[ns]
#  12  isOpen                  50000 non-null  int64
# ...

# %%
target = 'isOpen'

# %%
def mycorr(x,y=data[target]):
    mat = np.corrcoef(x,y)
    print(mat)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 50000 entries, 0 to 49999
# Data columns (total 16 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Time_given              50000 non-null  int64
#  1   Time_taken              40000 non-null  float64
#  2   Time_variance           40000 non-null  float64
#  3   baseline_create_date    50000 non-null  datetime64[ns]
#  4   business_code           50000 non-null  object
#  5   clear_date              40000 non-null  datetime64[ns]
#  6   cust_number             50000 non-null  object
#  7   cust_payment_terms      50000 non-null  object
#  8   delay                   40000 non-null  float64
#  9   document_create_date    50000 non-null  datetime64[ns]
#  10  document_create_date.1  50000 non-null  datetime64[ns]
#  11  due_in_date             50000 non-null  datetime64[ns]
#  12  isOpen                  50000 non-null  int64
# ...

# %%
mycorr(data['Time_given'])
# Out:
# [[ 1.         -0.02302441]
#  [-0.02302441  1.        ]]

# %%
mycorr(data['Time_taken'].notnull(),data['isOpen'])
# Out:
# [[ 1. -1.]
#  [-1.  1.]]

# %%
mycorr(data['Time_variance'].notnull(),data['Time_taken'].notnull())
# Out:
# [[1. 1.]
#  [1. 1.]]

# %%
data.shape
# Out:
# (50000, 16)

# %%
for i in data:
    if data[i].isnull().sum()>0:
        print(i,data[i].isnull().sum())
# Out:
# Time_taken 10000
# Time_variance 10000
# clear_date 10000
# delay 10000

# %%
data.head()
# Out:
#    Time_given  Time_taken  Time_variance baseline_create_date business_code  \
# 0          16       282.0          266.0           2020-01-26          U001
# 1          20        17.0           -3.0           2019-07-22          U001
# 2          15       107.0           92.0           2019-09-14          U001
# 3          11         NaN            NaN           2020-03-31          CA02
# 4          15        12.0           -3.0           2019-11-13          U001
#
#   clear_date cust_number cust_payment_terms  delay document_create_date  \
# 0 2020-11-02   200769623               NAH4  266.0           2020-01-25
# 1 2019-08-08   200980828               NAD1   -3.0           2019-07-22
# 2 2019-12-30   200792734               NAA8   92.0           2019-09-14
# 3        NaT   140105686               CA10    NaN           2020-03-30
# 4 2019-11-25   200769623               NAH4   -3.0           2019-11-13
#
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 50000 entries, 0 to 49999
# Data columns (total 16 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Time_given              50000 non-null  int64
#  1   Time_taken              40000 non-null  float64
#  2   Time_variance           40000 non-null  float64
#  3   baseline_create_date    50000 non-null  datetime64[ns]
#  4   business_code           50000 non-null  object
#  5   clear_date              40000 non-null  datetime64[ns]
#  6   cust_number             50000 non-null  object
#  7   cust_payment_terms      50000 non-null  object
#  8   delay                   40000 non-null  float64
#  9   document_create_date    50000 non-null  datetime64[ns]
#  10  document_create_date.1  50000 non-null  datetime64[ns]
#  11  due_in_date             50000 non-null  datetime64[ns]
#  12  isOpen                  50000 non-null  int64
# ...

# %%
data.describe()
# Out:
#          Time_given    Time_taken  Time_variance         delay        isOpen  \
# count  50000.000000  40000.000000   40000.000000  40000.000000  50000.000000
# mean      17.924740     19.918175       1.872750      1.872750      0.200000
# std       10.483327     91.087921      90.990873     90.990873      0.400004
# min      -50.000000   -291.000000    -326.000000   -326.000000      0.000000
# 25%       15.000000     11.000000      -5.000000     -5.000000      0.000000
# 50%       16.000000     16.000000       0.000000      0.000000      0.000000
# 75%       17.000000     33.000000       6.000000      6.000000      0.000000
# max      122.000000    338.000000     316.000000    316.000000      1.000000
#
#        total_open_amount
# count       5.000000e+04
# mean        2.345506e+06
# std         2.764850e+06
# min         5.378400e+01
# 25%         3.601862e+05
# 50%         1.297247e+06
# 75%         3.466986e+06
# max         4.994392e+07

# %%
data.nunique()
# Out:
# Time_given                  120
# Time_taken                  607
# Time_variance               595
# baseline_create_date        506
# business_code                 6
# clear_date                  403
# cust_number                1099
# cust_payment_terms           74
# delay                       595
# document_create_date        507
# document_create_date.1      506
# due_in_date                 547
# isOpen                        2
# name_customer              4197
# posting_date                506
# total_open_amount         44384
# dtype: int64

# %%
data.corr()
# Out:
#                    Time_given  Time_taken  Time_variance     delay    isOpen  \
# Time_given           1.000000    0.067826      -0.049759 -0.049759 -0.023024
# Time_taken           0.067826    1.000000       0.993086  0.993086       NaN
# Time_variance       -0.049759    0.993086       1.000000  1.000000       NaN
# delay               -0.049759    0.993086       1.000000  1.000000       NaN
# isOpen              -0.023024         NaN            NaN       NaN  1.000000
# total_open_amount   -0.065460   -0.009059      -0.001664 -0.001664  0.014640
#
#                    total_open_amount
# Time_given                 -0.065460
# Time_taken                 -0.009059
# Time_variance              -0.001664
# delay                      -0.001664
# isOpen                      0.014640
# total_open_amount           1.000000

# %%
data.cov()
# Out:
#                      Time_given    Time_taken  Time_variance          delay  \
# Time_given         1.099002e+02  6.614137e+01     -48.471006     -48.471006
# Time_taken         6.614137e+01  8.297009e+03    8230.867934    8230.867934
# Time_variance     -4.847101e+01  8.230868e+03    8279.338941    8279.338941
# delay             -4.847101e+01  8.230868e+03    8279.338941    8279.338941
# isOpen            -9.654993e-02  0.000000e+00       0.000000       0.000000
# total_open_amount -1.897353e+06 -2.296083e+06 -421173.919825 -421173.919825
#
#                          isOpen  total_open_amount
# Time_given            -0.096550      -1.897353e+06
# Time_taken             0.000000      -2.296083e+06
# Time_variance          0.000000      -4.211739e+05
# delay                  0.000000      -4.211739e+05
# isOpen                 0.160003       1.619109e+04
# total_open_amount  16191.093484       7.644397e+12

# %%
data.nunique()
# Out:
# Time_given                  120
# Time_taken                  607
# Time_variance               595
# baseline_create_date        506
# business_code                 6
# clear_date                  403
# cust_number                1099
# cust_payment_terms           74
# delay                       595
# document_create_date        507
# document_create_date.1      506
# due_in_date                 547
# isOpen                        2
# name_customer              4197
# posting_date                506
# total_open_amount         44384
# dtype: int64

# %%
orig = pd.read_csv('Dataset.csv',index_col=0)

# %%
print(orig.nunique())
# Out:
# cust_number                1099
# name_customer              4197
# clear_date                  403
# buisness_year                 2
# doc_id                    48839
# posting_date                506
# document_create_date        507
# document_create_date.1      506
# due_in_date                 547
# invoice_currency              2
# document type                 2
# posting_id                    1
# area_business                 0
# Unnamed: 14                  17
# total_open_amount         44349
# baseline_create_date        506
# cust_payment_terms           74
# invoice_id                48833
# isOpen                        2
# dtype: int64

# %%
data.nunique()
# Out:
# Time_given                  120
# Time_taken                  607
# Time_variance               595
# baseline_create_date        506
# business_code                 6
# clear_date                  403
# cust_number                1099
# cust_payment_terms           74
# delay                       595
# document_create_date        507
# document_create_date.1      506
# due_in_date                 547
# isOpen                        2
# name_customer              4197
# posting_date                506
# total_open_amount         44384
# dtype: int64

# %%
ls1 = data['name_customer'].unique()
len(ls1)
# Out:
# 4197

# %%
data['count'] = 1

# %%
data.head()
# Out:
#    Time_given  Time_taken  Time_variance baseline_create_date business_code  \
# 0          16       282.0          266.0           2020-01-26          U001
# 1          20        17.0           -3.0           2019-07-22          U001
# 2          15       107.0           92.0           2019-09-14          U001
# 3          11         NaN            NaN           2020-03-31          CA02
# 4          15        12.0           -3.0           2019-11-13          U001
#
#   clear_date cust_number cust_payment_terms  delay document_create_date  \
# 0 2020-11-02   200769623               NAH4  266.0           2020-01-25
# 1 2019-08-08   200980828               NAD1   -3.0           2019-07-22
# 2 2019-12-30   200792734               NAA8   92.0           2019-09-14
# 3        NaT   140105686               CA10    NaN           2020-03-30
# 4 2019-11-25   200769623               NAH4   -3.0           2019-11-13
#
# ...

# %%
ls = data.groupby('name_customer', as_index=False).sum()
for col in ls.columns:
    if col != 'name_customer':
        ls[col] = ls[col]/ls['count']
ls
# Out:
#              name_customer  Time_given  Time_taken  Time_variance  delay  \
# 0                 11078 us        11.0       -58.0          -69.0  -69.0
# 1         17135 associates        11.0         1.0          -10.0  -10.0
# 2                17135 llc        11.0         8.0           -3.0   -3.0
# 3              17135 trust        11.0         0.0            0.0    0.0
# 4                 17135 us        12.0         0.0            0.0    0.0
# ...                    ...         ...         ...            ...    ...
# 4192  YEN BROS corporation        19.5        19.0           -0.5   -0.5
# 4193          YEN BROS llc        19.0        17.0           -2.0   -2.0
# 4194              ZARCO co        13.0        12.0           -1.0   -1.0
# 4195           ZARCO trust        12.0         0.0            0.0    0.0
# 4196             ZIYAD  us       113.0        30.0          -83.0  -83.0
#
#       isOpen  total_open_amount  count
# 0        0.0       6.033024e+05    1.0
# ...

# %%
res = data.groupby('cust_number', as_index=False).sum()
for col in res.columns:
    if col != 'cust_number':
        res[col] = res[col]/res['count']
res
# Out:
#      cust_number  Time_given  Time_taken  Time_variance      delay    isOpen  \
# 0      100000048   92.000000  119.500000      27.500000  27.500000  0.000000
# 1      100000051   30.666667  101.000000      70.333333  70.333333  0.000000
# 2      100000158   90.571429   90.285714      -0.285714  -0.285714  0.000000
# 3      100000217   19.000000   47.500000      28.500000  28.500000  0.000000
# 4      100000222   18.470588   30.941176      16.176471  16.176471  0.205882
# ...          ...         ...         ...            ...        ...       ...
# 1094      CC7455   45.750000   54.750000       9.000000   9.000000  0.000000
# 1095      CCCA02   36.762195    4.050813     -29.121951 -29.121951  0.097561
# 1096      CCU001   36.145833   -0.333333     -31.083333 -31.083333  0.145833
# 1097      CCU002   37.465116   -0.728682     -35.806202 -35.806202  0.062016
# 1098      CCU013    1.960591    0.847291      -0.906404  -0.906404  0.110016
#
#       total_open_amount  count
# ...

# %%
data.shape
# Out:
# (50000, 17)

# %%
print(res.iloc[0])
# Out:
# cust_number             100000048
# Time_given                   92.0
# Time_taken                  119.5
# Time_variance                27.5
# delay                        27.5
# isOpen                        0.0
# total_open_amount    4650884.3745
# count                         1.0
# Name: 0, dtype: object

# %%
dups = data.pivot_table(index = ['name_customer'], aggfunc ='size')
for i in dups:
    if dups[i]>1:
        print(i)
# Out:
# 6
# 6
# 6
# 7
# 15
# 18
# 9
# 9
# 13
# 6
# 9
# 14
# 15
# 14
# 12
# 7
# 16
# 15
# 10
# 18
# 21
# 14
# 13
# 12
# 21
# 26
# 26
# 49
# 48
# 46
# 48
# 53
# 54
# 6
# 6
# 7
# 7
# 6
# 6
# 92
# 86
# 91
# 91
# 92
# 86
# 83
# 80
# 95
# 74
# 80
# 6
# 12
# 6
# 13
# 10
# 10
# 7
# 10
# 17
# 11
# 6
# 12
# 10
# 6
# 10
# 6
# 10
# 10
# 6
# 174
# 171
# 209
# 15
# 14
# 10
# 11
# 6
# 13
# 12
# 7
# 10
# 6
# 9
# 9
# 9
# 9
# 11
# 7
# 7
# 11
# 7
# 7
# 10
# 9
# 6
# 7
# 11
# 12
# 11
# 13
# 12
# 15
# 16
# 14
# 7
# 7
# 6
# 6
# 142
# 150
# 150
# 171
# 141
# 6
# 6
# 6
# 7
# 12
# 7
# 13
# 7
# 7
# 7
# 17
# 17
# 10
# 14
# 17
# 6
# 15
# 12
# 10
# 13
# 9
# 6
# 14
# 12
# 9
# 7
# 10
# 99
# 97
# 49
# 42
# 37
# 42
# 48
# 44
# 6
# 7
# 130
# 125
# 97
# 104
# 99
# 93
# 100
# 103
# 102
# 87
# 101
# 118
# 79
# 91
# 106
# 94
# 91
# 43
# 45
# 43
# 42
# 43
# 42
# 9
# 6
# 6
# 9
# 6
# 6
# 12
# 10
# 6
# 6
# 7
# 6
# 7
# 6
# 44
# 43
# 44
# 37
# 48
# 11
# 16
# 18
# 9
# 10
# 14
# 9
# 11
# 74
# 75
# 61
# 80
# 77
# 93
# 85
# 79
# 68
# 10
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 50000 entries, 0 to 49999
# Data columns (total 17 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Time_given              50000 non-null  int64
#  1   Time_taken              40000 non-null  float64
#  2   Time_variance           40000 non-null  float64
#  3   baseline_create_date    50000 non-null  datetime64[ns]
#  4   business_code           50000 non-null  object
#  5   clear_date              40000 non-null  datetime64[ns]
#  6   cust_number             50000 non-null  object
#  7   cust_payment_terms      50000 non-null  object
#  8   delay                   40000 non-null  float64
#  9   document_create_date    50000 non-null  datetime64[ns]
#  10  document_create_date.1  50000 non-null  datetime64[ns]
#  11  due_in_date             50000 non-null  datetime64[ns]
#  12  isOpen                  50000 non-null  int64
# ...

# %%
data.head()
# Out:
#    Time_given  Time_taken  Time_variance baseline_create_date business_code  \
# 0          16       282.0          266.0           2020-01-26          U001
# 1          20        17.0           -3.0           2019-07-22          U001
# 2          15       107.0           92.0           2019-09-14          U001
# 3          11         NaN            NaN           2020-03-31          CA02
# 4          15        12.0           -3.0           2019-11-13          U001
#
#   clear_date cust_number cust_payment_terms  delay document_create_date  \
# 0 2020-11-02   200769623               NAH4  266.0           2020-01-25
# 1 2019-08-08   200980828               NAD1   -3.0           2019-07-22
# 2 2019-12-30   200792734               NAA8   92.0           2019-09-14
# 3        NaT   140105686               CA10    NaN           2020-03-30
# 4 2019-11-25   200769623               NAH4   -3.0           2019-11-13
#
# ...

# %%
data.drop(['Time_given','Time_taken','Time_variance'],axis=1,inplace=True)

# %%
data.head()
# Out:
#   baseline_create_date business_code clear_date cust_number  \
# 0           2020-01-26          U001 2020-11-02   200769623
# 1           2019-07-22          U001 2019-08-08   200980828
# 2           2019-09-14          U001 2019-12-30   200792734
# 3           2020-03-31          CA02        NaT   140105686
# 4           2019-11-13          U001 2019-11-25   200769623
#
#   cust_payment_terms  delay document_create_date document_create_date.1  \
# 0               NAH4  266.0           2020-01-25             2020-01-26
# 1               NAD1   -3.0           2019-07-22             2019-07-22
# 2               NAA8   92.0           2019-09-14             2019-09-14
# 3               CA10    NaN           2020-03-30             2020-03-30
# 4               NAH4   -3.0           2019-11-13             2019-11-13
#
#   due_in_date  isOpen       name_customer posting_date  total_open_amount  \
# 0  2020-02-10       0        WAL-MAR corp   2020-01-26        4054214.016
# ...

# %%
data['isOpen'].value_counts()
# Out:
# 0    40000
# 1    10000
# Name: isOpen, dtype: int64

# %%
def split_name(df):
    def get_names(full_name):
        f_name= full_name.split(' ')[0]
        l_name = full_name.split(' ')[-1]
        if(len(full_name.split(' '))>2):
            m_name = full_name.split(' ')[1:-1]
        else:
            m_name  = ""
        return pd.Series(
            (f_name,m_name,l_name),
            index = ['First Name','Middle Name','Last Name']
        )
        
    names = df['name_customer'].apply(get_names)
    df[names.columns] = names
    return df
split_name(data)
# Out:
#       baseline_create_date business_code clear_date cust_number  \
# 0               2020-01-26          U001 2020-11-02   200769623
# 1               2019-07-22          U001 2019-08-08   200980828
# 2               2019-09-14          U001 2019-12-30   200792734
# 3               2020-03-31          CA02        NaT   140105686
# 4               2019-11-13          U001 2019-11-25   200769623
# ...                    ...           ...        ...         ...
# 49995           2020-04-21          U001        NaT   200561861
# 49996           2019-08-15          U001 2019-03-09   200769623
# 49997           2020-02-19          U001 2020-05-03   200772595
# 49998           2019-11-27          U001 2019-12-12   200726979
# 49999           2019-01-01          U001 2019-01-15   200020431
#
#       cust_payment_terms  delay document_create_date document_create_date.1  \
# 0                   NAH4  266.0           2020-01-25             2020-01-26
# ...

# %%
data
# Out:
#       baseline_create_date business_code clear_date cust_number  \
# 0               2020-01-26          U001 2020-11-02   200769623
# 1               2019-07-22          U001 2019-08-08   200980828
# 2               2019-09-14          U001 2019-12-30   200792734
# 3               2020-03-31          CA02        NaT   140105686
# 4               2019-11-13          U001 2019-11-25   200769623
# ...                    ...           ...        ...         ...
# 49995           2020-04-21          U001        NaT   200561861
# 49996           2019-08-15          U001 2019-03-09   200769623
# 49997           2020-02-19          U001 2020-05-03   200772595
# 49998           2019-11-27          U001 2019-12-12   200726979
# 49999           2019-01-01          U001 2019-01-15   200020431
#
#       cust_payment_terms  delay document_create_date document_create_date.1  \
# 0                   NAH4  266.0           2020-01-25             2020-01-26
# ...

# %%
data.shape
data.describe()
# Out:
#               delay        isOpen  total_open_amount    count
# count  40000.000000  50000.000000       5.000000e+04  50000.0
# mean       1.872750      0.200000       2.345506e+06      1.0
# std       90.990873      0.400004       2.764850e+06      0.0
# min     -326.000000      0.000000       5.378400e+01      1.0
# 25%       -5.000000      0.000000       3.601862e+05      1.0
# 50%        0.000000      0.000000       1.297247e+06      1.0
# 75%        6.000000      0.000000       3.466986e+06      1.0
# max      316.000000      1.000000       4.994392e+07      1.0

# %%
data.head()
# Out:
#   baseline_create_date business_code clear_date cust_number  \
# 0           2020-01-26          U001 2020-11-02   200769623
# 1           2019-07-22          U001 2019-08-08   200980828
# 2           2019-09-14          U001 2019-12-30   200792734
# 3           2020-03-31          CA02        NaT   140105686
# 4           2019-11-13          U001 2019-11-25   200769623
#
#   cust_payment_terms  delay document_create_date document_create_date.1  \
# 0               NAH4  266.0           2020-01-25             2020-01-26
# 1               NAD1   -3.0           2019-07-22             2019-07-22
# 2               NAA8   92.0           2019-09-14             2019-09-14
# 3               CA10    NaN           2020-03-30             2020-03-30
# 4               NAH4   -3.0           2019-11-13             2019-11-13
#
#   due_in_date  isOpen       name_customer posting_date  total_open_amount  \
# 0  2020-02-10       0        WAL-MAR corp   2020-01-26        4054214.016
# ...

# %%
data['First Name'].nunique()
# Out:
# 845

# %%
data['name_customer'].nunique()
# Out:
# 4197

# %%
data['cust_number'].nunique()
# Out:
# 1099

# %%
data['business_code'].value_counts()
# Out:
# U001    45359
# CA02     3917
# U013      573
# U002      135
# U005       11
# U007        5
# Name: business_code, dtype: int64

# %%
import re
def split_code(df):
    def get_code(code):
        label = re.findall("\D+",code)
        num = re.findall("\d+",code)
        return pd.Series(
            (label[0],int(num[0])),
            index = ['buisness_code_label','buisness_code_number']
        )
        
    codes = df['business_code'].apply(get_code)
    df[codes.columns] = codes
    return df
split_code(data)
# Out:
#       baseline_create_date business_code clear_date cust_number  \
# 0               2020-01-26          U001 2020-11-02   200769623
# 1               2019-07-22          U001 2019-08-08   200980828
# 2               2019-09-14          U001 2019-12-30   200792734
# 3               2020-03-31          CA02        NaT   140105686
# 4               2019-11-13          U001 2019-11-25   200769623
# ...                    ...           ...        ...         ...
# 49995           2020-04-21          U001        NaT   200561861
# 49996           2019-08-15          U001 2019-03-09   200769623
# 49997           2020-02-19          U001 2020-05-03   200772595
# 49998           2019-11-27          U001 2019-12-12   200726979
# 49999           2019-01-01          U001 2019-01-15   200020431
#
#       cust_payment_terms  delay document_create_date document_create_date.1  \
# 0                   NAH4  266.0           2020-01-25             2020-01-26
# ...

# %%
data.head()
# Out:
#   baseline_create_date business_code clear_date cust_number  \
# 0           2020-01-26          U001 2020-11-02   200769623
# 1           2019-07-22          U001 2019-08-08   200980828
# 2           2019-09-14          U001 2019-12-30   200792734
# 3           2020-03-31          CA02        NaT   140105686
# 4           2019-11-13          U001 2019-11-25   200769623
#
#   cust_payment_terms  delay document_create_date document_create_date.1  \
# 0               NAH4  266.0           2020-01-25             2020-01-26
# 1               NAD1   -3.0           2019-07-22             2019-07-22
# 2               NAA8   92.0           2019-09-14             2019-09-14
# 3               CA10    NaN           2020-03-30             2020-03-30
# 4               NAH4   -3.0           2019-11-13             2019-11-13
#
#   due_in_date  isOpen       name_customer posting_date  total_open_amount  \
# 0  2020-02-10       0        WAL-MAR corp   2020-01-26        4054214.016
# ...

# %%
data.dtypes
# Out:
# baseline_create_date      datetime64[ns]
# business_code                     object
# clear_date                datetime64[ns]
# cust_number                       object
# cust_payment_terms                object
# delay                            float64
# document_create_date      datetime64[ns]
# document_create_date.1    datetime64[ns]
# due_in_date               datetime64[ns]
# isOpen                             int64
# name_customer                     object
# posting_date              datetime64[ns]
# total_open_amount                float64
# count                              int64
# First Name                        object
# Middle Name                       object
# Last Name                         object
# buisness_code_label               object
# buisness_code_number               int64
# dtype: object

# %%
data.sort_index(axis=1,inplace=True)

# %%
data
# Out:
#       First Name    Last Name Middle Name baseline_create_date  \
# 0        WAL-MAR         corp                       2020-01-26
# 1            BEN                      [E]           2019-07-22
# 2           MDV/        trust                       2019-09-14
# 3           SYSC          llc                       2020-03-31
# 4        WAL-MAR   foundation                       2019-11-13
# ...          ...          ...         ...                  ...
# 49995         CO  corporation                       2020-04-21
# 49996    WAL-MAR           co                       2019-08-15
# 49997      SAFEW   associates                       2020-02-19
# 49998       BJ'S          llc          []           2019-11-27
# 49999        DEC         corp                       2019-01-01
#
#       buisness_code_label  buisness_code_number business_code clear_date  \
# 0                       U                     1          U001 2020-11-02
# ...

# %%
data.corr()
# Out:
#                       buisness_code_number  count     delay    isOpen  \
# buisness_code_number              1.000000    NaN  0.022865 -0.021785
# count                                  NaN    NaN       NaN       NaN
# delay                             0.022865    NaN  1.000000       NaN
# isOpen                           -0.021785    NaN       NaN  1.000000
# total_open_amount                -0.006907    NaN -0.001664  0.014640
#
#                       total_open_amount
# buisness_code_number          -0.006907
# count                               NaN
# delay                         -0.001664
# isOpen                         0.014640
# total_open_amount              1.000000

# %%
data['total_open_amount']
# Out:
# 0        4054214.016
# 1        5950348.020
# 2         168363.342
# 3         194055.357
# 4        2475056.763
#             ...
# 49995     238133.142
# 49996     505460.538
# 49997     457228.242
# 49998       4741.956
# 49999     133735.410
# Name: total_open_amount, Length: 50000, dtype: float64

# %%
data['total_open_amount']=data['total_open_amount'].round()

# %%
data['total_open_amount'].kurt()
# Out:
# 13.289691956758475

# %%
data.kurt()
# Out:
# C:\Users\KIIT\AppData\Local\Temp\ipykernel_8720\2907027414.py:1: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   data.kurt()
# buisness_code_number    74.340864
# count                    0.000000
# delay                    2.881408
# isOpen                   0.250145
# total_open_amount       13.289692
# dtype: float64

# %%
data.skew()
# Out:
# C:\Users\KIIT\AppData\Local\Temp\ipykernel_8720\1188251951.py:1: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   data.skew()
# buisness_code_number    8.554489
# count                   0.000000
# delay                  -0.018966
# isOpen                  1.500045
# total_open_amount       2.412468
# dtype: float64

# %%
data.to_csv('Dataset4.csv')

# %%
data
# Out:
#       First Name    Last Name Middle Name baseline_create_date  \
# 0        WAL-MAR         corp                       2020-01-26
# 1            BEN                      [E]           2019-07-22
# 2           MDV/        trust                       2019-09-14
# 3           SYSC          llc                       2020-03-31
# 4        WAL-MAR   foundation                       2019-11-13
# ...          ...          ...         ...                  ...
# 49995         CO  corporation                       2020-04-21
# 49996    WAL-MAR           co                       2019-08-15
# 49997      SAFEW   associates                       2020-02-19
# 49998       BJ'S          llc          []           2019-11-27
# 49999        DEC         corp                       2019-01-01
#
#       buisness_code_label  buisness_code_number business_code clear_date  \
# 0                       U                     1          U001 2020-11-02
# ...
