# %% [markdown]
# <h1>Importing Libraries

# %%
import pandas as pd
import numpy as np
import matplotlib as mlt
import statistics as stat
import seaborn as sns
from sklearn import preprocessing
import os
import datetime as dt

# %% [markdown]
# <h3>Importing Dataset

# %%
data = pd.read_csv('./Odataset.csv')

# %% [markdown]
# <h3>Droping Constant columns

# %%
data.head()
# Out:
#   business_code cust_number       name_customer        clear_date  \
# 0          U001   200769623        WAL-MAR corp  11-02-2020 00:00
# 1          U001   200980828              BEN E   08-08-2019 00:00
# 2          U001   200792734          MDV/ trust  30-12-2019 00:00
# 3          CA02   140105686            SYSC llc               NaN
# 4          U001   200769623  WAL-MAR foundation  25-11-2019 00:00
#
#    buisness_year      doc_id posting_date  document_create_date  \
# 0           2020  1930438491   26-01-2020              20200125
# 1           2019  1929646410   22-07-2019              20190722
# 2           2019  1929873765   14-09-2019              20190914
# 3           2020  2960623488   30-03-2020              20200330
# 4           2019  1930147974   13-11-2019              20191113
#
#    document_create_date.1  due_in_date invoice_currency document type  \
# 0                20200126     20200210              USD            RV
# ...

# %%
data.drop(['doc_id','posting_id','area_business','invoice_id'],axis=1,inplace=True)

# %%
data.drop(['buisness_year'],axis=1,inplace=True)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 50000 entries, 0 to 49999
# Data columns (total 14 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   business_code           50000 non-null  object
#  1   cust_number             50000 non-null  object
#  2   name_customer           50000 non-null  object
#  3   clear_date              40000 non-null  object
#  4   posting_date            50000 non-null  object
#  5   document_create_date    50000 non-null  int64
#  6   document_create_date.1  50000 non-null  int64
#  7   due_in_date             50000 non-null  int64
#  8   invoice_currency        50000 non-null  object
#  9   document type           50000 non-null  object
#  10  total_open_amount       50000 non-null  float64
#  11  baseline_create_date    50000 non-null  int64
#  12  cust_payment_terms      50000 non-null  object
#  13  isOpen                  50000 non-null  int64
# ...

# %%
data.nunique()
# Out:
# business_code                 6
# cust_number                1099
# name_customer              4197
# clear_date                  403
# posting_date                506
# document_create_date        507
# document_create_date.1      506
# due_in_date                 547
# invoice_currency              2
# document type                 2
# total_open_amount         44349
# baseline_create_date        506
# cust_payment_terms           74
# isOpen                        2
# dtype: int64

# %%
data
# Out:
#       business_code cust_number       name_customer        clear_date  \
# 0              U001   200769623        WAL-MAR corp  11-02-2020 00:00
# 1              U001   200980828              BEN E   08-08-2019 00:00
# 2              U001   200792734          MDV/ trust  30-12-2019 00:00
# 3              CA02   140105686            SYSC llc               NaN
# 4              U001   200769623  WAL-MAR foundation  25-11-2019 00:00
# ...             ...         ...                 ...               ...
# 49995          U001   200561861      CO corporation               NaN
# 49996          U001   200769623          WAL-MAR co  03-09-2019 00:00
# 49997          U001   200772595    SAFEW associates  05-03-2020 00:00
# 49998          U001   200726979           BJ'S  llc  12-12-2019 00:00
# 49999          U001   200020431            DEC corp  15-01-2019 00:00
#
#       posting_date  document_create_date  document_create_date.1  due_in_date  \
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 50000 entries, 0 to 49999
# Data columns (total 14 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   business_code           50000 non-null  object
#  1   cust_number             50000 non-null  object
#  2   name_customer           50000 non-null  object
#  3   clear_date              40000 non-null  datetime64[ns]
#  4   posting_date            50000 non-null  datetime64[ns]
#  5   document_create_date    50000 non-null  int64
#  6   document_create_date.1  50000 non-null  int64
#  7   due_in_date             50000 non-null  int64
#  8   invoice_currency        50000 non-null  object
#  9   document type           50000 non-null  object
#  10  total_open_amount       50000 non-null  float64
#  11  baseline_create_date    50000 non-null  int64
#  12  cust_payment_terms      50000 non-null  object
#  13  isOpen                  50000 non-null  int64
# ...

# %% [markdown]
# <h3>Datetime conversion

# %%
data['clear_date']= pd.to_datetime(data['clear_date'])
data['posting_date']= pd.to_datetime(data['posting_date'])

# %%
data['document_create_date']= pd.to_datetime(data['document_create_date'],format='%Y%m%d')
data['document_create_date.1']= pd.to_datetime(data['document_create_date.1'],format='%Y%m%d')
data['due_in_date']= pd.to_datetime(data['due_in_date'],format='%Y%m%d')
data['baseline_create_date']= pd.to_datetime(data['baseline_create_date'],format='%Y%m%d')

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 50000 entries, 0 to 49999
# Data columns (total 14 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   business_code           50000 non-null  object
#  1   cust_number             50000 non-null  object
#  2   name_customer           50000 non-null  object
#  3   clear_date              40000 non-null  datetime64[ns]
#  4   posting_date            50000 non-null  datetime64[ns]
#  5   document_create_date    50000 non-null  datetime64[ns]
#  6   document_create_date.1  50000 non-null  datetime64[ns]
#  7   due_in_date             50000 non-null  datetime64[ns]
#  8   invoice_currency        50000 non-null  object
#  9   document type           50000 non-null  object
#  10  total_open_amount       50000 non-null  float64
#  11  baseline_create_date    50000 non-null  datetime64[ns]
#  12  cust_payment_terms      50000 non-null  object
# ...

# %%
data
# Out:
#       business_code cust_number       name_customer clear_date posting_date  \
# 0              U001   200769623        WAL-MAR corp 2020-11-02   2020-01-26
# 1              U001   200980828              BEN E  2019-08-08   2019-07-22
# 2              U001   200792734          MDV/ trust 2019-12-30   2019-09-14
# 3              CA02   140105686            SYSC llc        NaT   2020-03-30
# 4              U001   200769623  WAL-MAR foundation 2019-11-25   2019-11-13
# ...             ...         ...                 ...        ...          ...
# 49995          U001   200561861      CO corporation        NaT   2020-04-21
# 49996          U001   200769623          WAL-MAR co 2019-03-09   2019-08-15
# 49997          U001   200772595    SAFEW associates 2020-05-03   2020-02-19
# 49998          U001   200726979           BJ'S  llc 2019-12-12   2019-11-27
# 49999          U001   200020431            DEC corp 2019-01-15   2019-05-01
#
# ...

# %% [markdown]
# <h3>Currency Conversion

# %%
rate_cad = .75

# %%
# convert couurency
data.replace({"invoice_currency": {"USD": 1, "CAD": rate_cad}}, inplace=True)
data['total_open_amount'] = data['total_open_amount']*data['invoice_currency']

# %%
data.drop(['invoice_currency'],axis=1,inplace=True)

# %%
data
# Out:
#       business_code cust_number       name_customer clear_date posting_date  \
# 0              U001   200769623        WAL-MAR corp 2020-11-02   2020-01-26
# 1              U001   200980828              BEN E  2019-08-08   2019-07-22
# 2              U001   200792734          MDV/ trust 2019-12-30   2019-09-14
# 3              CA02   140105686            SYSC llc        NaT   2020-03-30
# 4              U001   200769623  WAL-MAR foundation 2019-11-25   2019-11-13
# ...             ...         ...                 ...        ...          ...
# 49995          U001   200561861      CO corporation        NaT   2020-04-21
# 49996          U001   200769623          WAL-MAR co 2019-03-09   2019-08-15
# 49997          U001   200772595    SAFEW associates 2020-05-03   2020-02-19
# 49998          U001   200726979           BJ'S  llc 2019-12-12   2019-11-27
# 49999          U001   200020431            DEC corp 2019-01-15   2019-05-01
#
# ...

# %% [markdown]
# <h3>Delay Date Calculation

# %%
data['delay'] = data['clear_date']-data['due_in_date']

# %%
data.delay = data.delay.dt.days

# %%
data.sort_index()
# Out:
#       business_code cust_number       name_customer clear_date posting_date  \
# 0              U001   200769623        WAL-MAR corp 2020-11-02   2020-01-26
# 1              U001   200980828              BEN E  2019-08-08   2019-07-22
# 2              U001   200792734          MDV/ trust 2019-12-30   2019-09-14
# 3              CA02   140105686            SYSC llc        NaT   2020-03-30
# 4              U001   200769623  WAL-MAR foundation 2019-11-25   2019-11-13
# ...             ...         ...                 ...        ...          ...
# 49995          U001   200561861      CO corporation        NaT   2020-04-21
# 49996          U001   200769623          WAL-MAR co 2019-03-09   2019-08-15
# 49997          U001   200772595    SAFEW associates 2020-05-03   2020-02-19
# 49998          U001   200726979           BJ'S  llc 2019-12-12   2019-11-27
# 49999          U001   200020431            DEC corp 2019-01-15   2019-05-01
#
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 50000 entries, 0 to 49999
# Data columns (total 15 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   business_code           50000 non-null  object
#  1   cust_number             50000 non-null  object
#  2   name_customer           50000 non-null  object
#  3   clear_date              40000 non-null  datetime64[ns]
#  4   posting_date            50000 non-null  datetime64[ns]
#  5   document_create_date    50000 non-null  datetime64[ns]
#  6   document_create_date.1  50000 non-null  datetime64[ns]
#  7   due_in_date             50000 non-null  datetime64[ns]
#  8   document type           50000 non-null  object
#  9   total_open_amount       50000 non-null  float64
#  10  baseline_create_date    50000 non-null  datetime64[ns]
#  11  cust_payment_terms      50000 non-null  object
#  12  isOpen                  50000 non-null  int64
# ...

# %%
data.drop(['total_open_amount_1'],axis=1,inplace=True)

# %%
data.head()
# Out:
#   business_code cust_number       name_customer clear_date posting_date  \
# 0          U001   200769623        WAL-MAR corp 2020-11-02   2020-01-26
# 1          U001   200980828              BEN E  2019-08-08   2019-07-22
# 2          U001   200792734          MDV/ trust 2019-12-30   2019-09-14
# 3          CA02   140105686            SYSC llc        NaT   2020-03-30
# 4          U001   200769623  WAL-MAR foundation 2019-11-25   2019-11-13
#
#   document_create_date document_create_date.1 due_in_date document type  \
# 0           2020-01-25             2020-01-26  2020-02-10            RV
# 1           2019-07-22             2019-07-22  2019-08-11            RV
# 2           2019-09-14             2019-09-14  2019-09-29            RV
# 3           2020-03-30             2020-03-30  2020-04-10            RV
# 4           2019-11-13             2019-11-13  2019-11-28            RV
#
#    total_open_amount baseline_create_date cust_payment_terms  isOpen  delay
# ...

# %%
data.to_csv('./f1.csv',index=False)

# %%
temp = pd.read_csv('./f1.csv')

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 50000 entries, 0 to 49999
# Data columns (total 15 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   business_code           50000 non-null  object
#  1   cust_number             50000 non-null  object
#  2   name_customer           50000 non-null  object
#  3   clear_date              40000 non-null  datetime64[ns]
#  4   posting_date            50000 non-null  datetime64[ns]
#  5   document_create_date    50000 non-null  datetime64[ns]
#  6   document_create_date.1  50000 non-null  datetime64[ns]
#  7   due_in_date             50000 non-null  datetime64[ns]
#  8   document type           50000 non-null  object
#  9   total_open_amount       50000 non-null  float64
#  10  baseline_create_date    50000 non-null  datetime64[ns]
#  11  cust_payment_terms      50000 non-null  object
#  12  isOpen                  50000 non-null  int64
# ...

# %%
temp.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 50000 entries, 0 to 49999
# Data columns (total 15 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   business_code           50000 non-null  object
#  1   cust_number             50000 non-null  object
#  2   name_customer           50000 non-null  object
#  3   clear_date              40000 non-null  object
#  4   posting_date            50000 non-null  object
#  5   document_create_date    50000 non-null  object
#  6   document_create_date.1  50000 non-null  object
#  7   due_in_date             50000 non-null  object
#  8   document type           50000 non-null  object
#  9   total_open_amount       50000 non-null  float64
#  10  baseline_create_date    50000 non-null  object
#  11  cust_payment_terms      50000 non-null  object
#  12  isOpen                  50000 non-null  int64
#  13  total_open_amount_1     50000 non-null  float64
# ...
