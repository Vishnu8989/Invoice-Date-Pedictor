# %%
import datetime
import pandas as pd
import numpy as np
import matplotlib as mtl
from sklearn.model_selection import train_test_split

from sklearn.feature_selection import VarianceThreshold

# %%
data = pd.read_csv('Dataset2.csv',index_col=[0])

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 50000 entries, 0 to 49999
# Data columns (total 12 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   business_code           50000 non-null  object
#  1   cust_number             50000 non-null  object
#  2   name_customer           50000 non-null  object
#  3   clear_date              40000 non-null  object
#  4   posting_date            50000 non-null  object
#  5   document_create_date    50000 non-null  int64
#  6   document_create_date.1  50000 non-null  int64
#  7   due_in_date             50000 non-null  int64
#  8   total_open_amount       50000 non-null  float64
#  9   baseline_create_date    50000 non-null  int64
#  10  cust_payment_terms      50000 non-null  object
#  11  isOpen                  50000 non-null  int64
# dtypes: float64(1), int64(5), object(6)
# memory usage: 5.0+ MB

# %%
data.head()
# Out:
#   business_code cust_number       name_customer        clear_date  \
# 0          U001   200769623        WAL-MAR corp  11-02-2020 00:00
# 1          U001   200980828              BEN E   08-08-2019 00:00
# 2          U001   200792734          MDV/ trust  30-12-2019 00:00
# 3          CA02   140105686            SYSC llc               NaN
# 4          U001   200769623  WAL-MAR foundation  25-11-2019 00:00
#
#   posting_date  document_create_date  document_create_date.1  due_in_date  \
# 0   26-01-2020              20200125                20200126     20200210
# 1   22-07-2019              20190722                20190722     20190811
# 2   14-09-2019              20190914                20190914     20190929
# 3   30-03-2020              20200330                20200330     20200410
# 4   13-11-2019              20191113                20191113     20191128
#
#    total_open_amount  baseline_create_date cust_payment_terms  isOpen
# ...

# %%
print(data['clear_date'].nunique())
print(data['clear_date'].dtype)
# Out:
# 403
# object

# %%
data['clear_date']= pd.to_datetime(data['clear_date'])

# %%
print(data['clear_date'].dtype)
data.head()
# Out:
# datetime64[ns]
#   business_code cust_number       name_customer clear_date posting_date  \
# 0          U001   200769623        WAL-MAR corp 2020-11-02   26-01-2020
# 1          U001   200980828              BEN E  2019-08-08   22-07-2019
# 2          U001   200792734          MDV/ trust 2019-12-30   14-09-2019
# 3          CA02   140105686            SYSC llc        NaT   30-03-2020
# 4          U001   200769623  WAL-MAR foundation 2019-11-25   13-11-2019
#
#    document_create_date  document_create_date.1  due_in_date  \
# 0              20200125                20200126     20200210
# 1              20190722                20190722     20190811
# 2              20190914                20190914     20190929
# 3              20200330                20200330     20200410
# 4              20191113                20191113     20191128
#
#    total_open_amount  baseline_create_date cust_payment_terms  isOpen
# 0        4054214.016              20200126               NAH4       0
# ...

# %%
print(data['posting_date'].nunique())
print(data['posting_date'].dtype)
# Out:
# 506
# object

# %%
data['posting_date']= pd.to_datetime(data['posting_date'])
# Out:
# C:\src\lib\site-packages\pandas\core\tools\datetimes.py:1047: UserWarning: Parsing '26-01-2020' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cache_array = _maybe_cache(arg, format, cache, convert_listlike)
# C:\src\lib\site-packages\pandas\core\tools\datetimes.py:1047: UserWarning: Parsing '22-07-2019' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cache_array = _maybe_cache(arg, format, cache, convert_listlike)
# C:\src\lib\site-packages\pandas\core\tools\datetimes.py:1047: UserWarning: Parsing '14-09-2019' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cache_array = _maybe_cache(arg, format, cache, convert_listlike)
# C:\src\lib\site-packages\pandas\core\tools\datetimes.py:1047: UserWarning: Parsing '30-03-2020' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
# ...

# %%
print(data['posting_date'].dtype)
data.head()
# Out:
# datetime64[ns]
#   business_code cust_number       name_customer clear_date posting_date  \
# 0          U001   200769623        WAL-MAR corp 2020-11-02   2020-01-26
# 1          U001   200980828              BEN E  2019-08-08   2019-07-22
# 2          U001   200792734          MDV/ trust 2019-12-30   2019-09-14
# 3          CA02   140105686            SYSC llc        NaT   2020-03-30
# 4          U001   200769623  WAL-MAR foundation 2019-11-25   2019-11-13
#
#    document_create_date  document_create_date.1  due_in_date  \
# 0              20200125                20200126     20200210
# 1              20190722                20190722     20190811
# 2              20190914                20190914     20190929
# 3              20200330                20200330     20200410
# 4              20191113                20191113     20191128
#
#    total_open_amount  baseline_create_date cust_payment_terms  isOpen
# 0        4054214.016              20200126               NAH4       0
# ...

# %%
dcd = 'document_create_date'
print(data[dcd].nunique())
print(data[dcd].dtype)
# Out:
# 507
# int64

# %%
data[dcd] = pd.to_datetime(data[dcd],format="%Y%m%d")

# %%
data.head()
# Out:
#   business_code cust_number       name_customer clear_date posting_date  \
# 0          U001   200769623        WAL-MAR corp 2020-11-02   2020-01-26
# 1          U001   200980828              BEN E  2019-08-08   2019-07-22
# 2          U001   200792734          MDV/ trust 2019-12-30   2019-09-14
# 3          CA02   140105686            SYSC llc        NaT   2020-03-30
# 4          U001   200769623  WAL-MAR foundation 2019-11-25   2019-11-13
#
#   document_create_date  document_create_date.1  due_in_date  \
# 0           2020-01-25                20200126     20200210
# 1           2019-07-22                20190722     20190811
# 2           2019-09-14                20190914     20190929
# 3           2020-03-30                20200330     20200410
# 4           2019-11-13                20191113     20191128
#
#    total_open_amount  baseline_create_date cust_payment_terms  isOpen
# 0        4054214.016              20200126               NAH4       0
# ...

# %%
dcd = 'document_create_date.1'
print(data[dcd].nunique())
print(data[dcd].dtype)
# Out:
# 506
# int64

# %%
data[dcd] = pd.to_datetime(data[dcd],format="%Y%m%d")

# %%
data.head()
# Out:
#   business_code cust_number       name_customer clear_date posting_date  \
# 0          U001   200769623        WAL-MAR corp 2020-11-02   2020-01-26
# 1          U001   200980828              BEN E  2019-08-08   2019-07-22
# 2          U001   200792734          MDV/ trust 2019-12-30   2019-09-14
# 3          CA02   140105686            SYSC llc        NaT   2020-03-30
# 4          U001   200769623  WAL-MAR foundation 2019-11-25   2019-11-13
#
#   document_create_date document_create_date.1  due_in_date  total_open_amount  \
# 0           2020-01-25             2020-01-26     20200210        4054214.016
# 1           2019-07-22             2019-07-22     20190811        5950348.020
# 2           2019-09-14             2019-09-14     20190929         168363.342
# 3           2020-03-30             2020-03-30     20200410         194055.357
# 4           2019-11-13             2019-11-13     20191128        2475056.763
#
#    baseline_create_date cust_payment_terms  isOpen
# ...

# %%
dcd = 'due_in_date'
print(data[dcd].nunique())
print(data[dcd].dtype)
# Out:
# 547
# int64

# %%
data[dcd] = pd.to_datetime(data[dcd],format="%Y%m%d")

# %%
data.head()
# Out:
#   business_code cust_number       name_customer clear_date posting_date  \
# 0          U001   200769623        WAL-MAR corp 2020-11-02   2020-01-26
# 1          U001   200980828              BEN E  2019-08-08   2019-07-22
# 2          U001   200792734          MDV/ trust 2019-12-30   2019-09-14
# 3          CA02   140105686            SYSC llc        NaT   2020-03-30
# 4          U001   200769623  WAL-MAR foundation 2019-11-25   2019-11-13
#
#   document_create_date document_create_date.1 due_in_date  total_open_amount  \
# 0           2020-01-25             2020-01-26  2020-02-10        4054214.016
# 1           2019-07-22             2019-07-22  2019-08-11        5950348.020
# 2           2019-09-14             2019-09-14  2019-09-29         168363.342
# 3           2020-03-30             2020-03-30  2020-04-10         194055.357
# 4           2019-11-13             2019-11-13  2019-11-28        2475056.763
#
#    baseline_create_date cust_payment_terms  isOpen
# ...

# %%
dcd = 'baseline_create_date'
print(data[dcd].nunique())
print(data[dcd].dtype)
# Out:
# 506
# int64

# %%
data[dcd] = pd.to_datetime(data[dcd],format="%Y%m%d")

# %%
data.head()
# Out:
#   business_code cust_number       name_customer clear_date posting_date  \
# 0          U001   200769623        WAL-MAR corp 2020-11-02   2020-01-26
# 1          U001   200980828              BEN E  2019-08-08   2019-07-22
# 2          U001   200792734          MDV/ trust 2019-12-30   2019-09-14
# 3          CA02   140105686            SYSC llc        NaT   2020-03-30
# 4          U001   200769623  WAL-MAR foundation 2019-11-25   2019-11-13
#
#   document_create_date document_create_date.1 due_in_date  total_open_amount  \
# 0           2020-01-25             2020-01-26  2020-02-10        4054214.016
# 1           2019-07-22             2019-07-22  2019-08-11        5950348.020
# 2           2019-09-14             2019-09-14  2019-09-29         168363.342
# 3           2020-03-30             2020-03-30  2020-04-10         194055.357
# 4           2019-11-13             2019-11-13  2019-11-28        2475056.763
#
#   baseline_create_date cust_payment_terms  isOpen
# ...

# %%
data['delay'] = (data['clear_date'] - data['due_in_date']).dt.days

# %%
data.head()
# Out:
#   business_code cust_number       name_customer clear_date posting_date  \
# 0          U001   200769623        WAL-MAR corp 2020-11-02   2020-01-26
# 1          U001   200980828              BEN E  2019-08-08   2019-07-22
# 2          U001   200792734          MDV/ trust 2019-12-30   2019-09-14
# 3          CA02   140105686            SYSC llc        NaT   2020-03-30
# 4          U001   200769623  WAL-MAR foundation 2019-11-25   2019-11-13
#
#   document_create_date document_create_date.1 due_in_date  total_open_amount  \
# 0           2020-01-25             2020-01-26  2020-02-10        4054214.016
# 1           2019-07-22             2019-07-22  2019-08-11        5950348.020
# 2           2019-09-14             2019-09-14  2019-09-29         168363.342
# 3           2020-03-30             2020-03-30  2020-04-10         194055.357
# 4           2019-11-13             2019-11-13  2019-11-28        2475056.763
#
#   baseline_create_date cust_payment_terms  isOpen  delay
# ...

# %%
data.to_csv('Dataset3.csv')

# %%
# data = pd.read_csv('Dataset3.csv',index_col=[0])

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 50000 entries, 0 to 49999
# Data columns (total 13 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   business_code           50000 non-null  object
#  1   cust_number             50000 non-null  object
#  2   name_customer           50000 non-null  object
#  3   clear_date              40000 non-null  datetime64[ns]
#  4   posting_date            50000 non-null  datetime64[ns]
#  5   document_create_date    50000 non-null  datetime64[ns]
#  6   document_create_date.1  50000 non-null  datetime64[ns]
#  7   due_in_date             50000 non-null  datetime64[ns]
#  8   total_open_amount       50000 non-null  float64
#  9   baseline_create_date    50000 non-null  datetime64[ns]
#  10  cust_payment_terms      50000 non-null  object
#  11  isOpen                  50000 non-null  int64
#  12  delay                   40000 non-null  float64
# ...

# %%
data['posting_date']
# Out:
# 0       2020-01-26
# 1       2019-07-22
# 2       2019-09-14
# 3       2020-03-30
# 4       2019-11-13
#            ...
# 49995   2020-04-21
# 49996   2019-08-15
# 49997   2020-02-19
# 49998   2019-11-27
# 49999   2019-05-01
# Name: posting_date, Length: 50000, dtype: datetime64[ns]

# %%
data.head()
# Out:
#   business_code cust_number       name_customer clear_date posting_date  \
# 0          U001   200769623        WAL-MAR corp 2020-11-02   2020-01-26
# 1          U001   200980828              BEN E  2019-08-08   2019-07-22
# 2          U001   200792734          MDV/ trust 2019-12-30   2019-09-14
# 3          CA02   140105686            SYSC llc        NaT   2020-03-30
# 4          U001   200769623  WAL-MAR foundation 2019-11-25   2019-11-13
#
#   document_create_date document_create_date.1 due_in_date  total_open_amount  \
# 0           2020-01-25             2020-01-26  2020-02-10        4054214.016
# 1           2019-07-22             2019-07-22  2019-08-11        5950348.020
# 2           2019-09-14             2019-09-14  2019-09-29         168363.342
# 3           2020-03-30             2020-03-30  2020-04-10         194055.357
# 4           2019-11-13             2019-11-13  2019-11-28        2475056.763
#
#   baseline_create_date cust_payment_terms  isOpen  delay
# ...

# %%
data['Time_given'] = pd.DataFrame(data['due_in_date']-data['posting_date'])
data['Time_given'].head()
# Out:
# 0   15 days
# 1   20 days
# 2   15 days
# 3   11 days
# 4   15 days
# Name: Time_given, dtype: timedelta64[ns]

# %%
data['Time_taken'] = pd.DataFrame(data['clear_date']-data['posting_date'])
data['Time_taken'].head()
# Out:
# 0   281 days
# 1    17 days
# 2   107 days
# 3        NaT
# 4    12 days
# Name: Time_taken, dtype: timedelta64[ns]

# %%
data['Time_variance'] = pd.DataFrame(data['clear_date']-data['due_in_date'])
data['Time_variance'].head()
# Out:
# 0   266 days
# 1    -3 days
# 2    92 days
# 3        NaT
# 4    -3 days
# Name: Time_variance, dtype: timedelta64[ns]

# %%
data.head()
# Out:
#   business_code cust_number       name_customer clear_date posting_date  \
# 0          U001   200769623        WAL-MAR corp 2020-11-02   2020-01-26
# 1          U001   200980828              BEN E  2019-08-08   2019-07-22
# 2          U001   200792734          MDV/ trust 2019-12-30   2019-09-14
# 3          CA02   140105686            SYSC llc        NaT   2020-03-30
# 4          U001   200769623  WAL-MAR foundation 2019-11-25   2019-11-13
#
#   document_create_date document_create_date.1 due_in_date  total_open_amount  \
# 0           2020-01-25             2020-01-26  2020-02-10        4054214.016
# 1           2019-07-22             2019-07-22  2019-08-11        5950348.020
# 2           2019-09-14             2019-09-14  2019-09-29         168363.342
# 3           2020-03-30             2020-03-30  2020-04-10         194055.357
# 4           2019-11-13             2019-11-13  2019-11-28        2475056.763
#
# ...

# %%
data.to_csv('Dataset3.csv')
temp = pd.read_csv('Dataset3.csv',index_col=[0])

# %%
temp.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 50000 entries, 0 to 49999
# Data columns (total 16 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   business_code           50000 non-null  object
#  1   cust_number             50000 non-null  object
#  2   name_customer           50000 non-null  object
#  3   clear_date              40000 non-null  object
#  4   posting_date            50000 non-null  object
#  5   document_create_date    50000 non-null  object
#  6   document_create_date.1  50000 non-null  object
#  7   due_in_date             50000 non-null  object
#  8   total_open_amount       50000 non-null  float64
#  9   baseline_create_date    50000 non-null  object
#  10  cust_payment_terms      50000 non-null  object
#  11  isOpen                  50000 non-null  int64
#  12  delay                   40000 non-null  float64
#  13  Time_given              50000 non-null  object
# ...

# %%
temp.head()
# Out:
#   business_code cust_number       name_customer  clear_date posting_date  \
# 0          U001   200769623        WAL-MAR corp  2020-11-02   2020-01-26
# 1          U001   200980828              BEN E   2019-08-08   2019-07-22
# 2          U001   200792734          MDV/ trust  2019-12-30   2019-09-14
# 3          CA02   140105686            SYSC llc         NaN   2020-03-30
# 4          U001   200769623  WAL-MAR foundation  2019-11-25   2019-11-13
#
#   document_create_date document_create_date.1 due_in_date  total_open_amount  \
# 0           2020-01-25             2020-01-26  2020-02-10        4054214.016
# 1           2019-07-22             2019-07-22  2019-08-11        5950348.020
# 2           2019-09-14             2019-09-14  2019-09-29         168363.342
# 3           2020-03-30             2020-03-30  2020-04-10         194055.357
# 4           2019-11-13             2019-11-13  2019-11-28        2475056.763
#
# ...

# %%
temp.shape
# Out:
# (50000, 16)
